# %%
import pandas as pd

# %%
df = pd.read_csv('players.csv')

# %%
df
# Out:
#         Rk             Player   Nation    Pos        Squad  \
# 0        1         Max Aarons  eng ENG     DF  Bournemouth
# 1        2         Max Aarons  eng ENG     MF     Valencia
# 2        3     Rodrigo Abajas   es ESP     DF     Valencia
# 3        4     James Abankwah   ie IRL  DF,MF      Udinese
# 4        5  Keyliane Abdallah   fr FRA     FW    Marseille
# ...    ...                ...      ...    ...          ...
# 2693  2693       Edhy Zuliani   it ITA     DF     Toulouse
# 2694  2694   Szymon Żurkowski   pl POL     MF       Empoli
# 2695  2695    Martin Ødegaard   no NOR     MF      Arsenal
# 2696  2696        Milan Đurić   ba BIH     FW        Monza
# 2697  2697        Milan Đurić   ba BIH     FW        Parma
#
#                     Comp   Age    Born  MP  Starts  ...  Att (GK)  Thr  \
# 0     eng Premier League  25.0  2000.0   3       1  ...       NaN  NaN
# 1             es La Liga  25.0  2000.0   1       0  ...       NaN  NaN
# ...

# %%
sum(df['Thr'].isnull())
# Out:
# 2514
